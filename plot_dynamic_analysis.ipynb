# %%
import matplotlib.pyplot as plt
import numpy as np

# cols = ['#fab36e', '#fa977d', '#ea8391', '#ca77a2', '#9f72aa', '#6c6ea5', '#376794']

# Load the data from the file
with open('3_iterations/dynamic_25_times.txt', 'r') as f:
    times1 = [float(line.strip()) for line in f]

with open('3_iterations/dynamic_50_times.txt', 'r') as f:
    times2 = [float(line.strip()) for line in f]

with open('3_iterations/dynamic_100_times.txt', 'r') as f:
    times3 = [float(line.strip()) for line in f]

with open('3_iterations/dynamic_200_times.txt', 'r') as f:
    times4 = [float(line.strip()) for line in f]

# Create an array for the indices
nodes1 = np.arange(25, 2501, 25)
nodes2 = np.arange(50, 2501, 50)
nodes3 = np.arange(100, 2501, 100)
nodes4 = np.arange(200, 2501, 200)

# Create the plot
fig, ax = plt.subplots()
ax.set_prop_cycle(color=cols)
plt.plot(nodes1, times1, marker='x', label='25 nodes')
plt.plot(nodes2, times2, marker='x', label='50 nodes')
plt.plot(nodes3, times3, marker='x', label='100 nodes')
plt.plot(nodes4, times4, marker='x', label='200 nodes')

# Add title and labels
plt.title('Compositional Analysis')
plt.xlabel('Number of nodes')
plt.ylabel('Inference time (s)')
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# cols = ['#fab36e', '#fa977d', '#ea8391', '#ca77a2', '#9f72aa', '#6c6ea5', '#376794']

# Load the data from the file
with open('5_iterations/dynamic_25_times.txt', 'r') as f:
    times1 = [float(line.strip()) for line in f]

with open('5_iterations/dynamic_50_times.txt', 'r') as f:
    times2 = [float(line.strip()) for line in f]

with open('5_iterations/dynamic_100_times.txt', 'r') as f:
    times3 = [float(line.strip()) for line in f]

with open('5_iterations/dynamic_200_times.txt', 'r') as f:
    times4 = [float(line.strip()) for line in f]

# Create an array for the indices
nodes1 = np.arange(25, 2501, 25)
nodes2 = np.arange(50, 2501, 50)
nodes3 = np.arange(100, 2501, 100)
nodes4 = np.arange(200, 2501, 200)

# Create the plot
fig, ax = plt.subplots()
ax.set_prop_cycle(color=cols)
plt.plot(nodes1, times1, marker='x', label='25 nodes')
plt.plot(nodes2, times2, marker='x', label='50 nodes')
plt.plot(nodes3, times3, marker='x', label='100 nodes')
plt.plot(nodes4, times4, marker='x', label='200 nodes')

# Add title and labels
plt.title('Compositional Analysis')
plt.xlabel('Number of nodes')
plt.ylabel('Inference time (s)')
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# cols = ['#fab36e', '#fa977d', '#ea8391', '#ca77a2', '#9f72aa', '#6c6ea5', '#376794']

# Load the data from the file
with open('7_iterations/dynamic_25_times.txt', 'r') as f:
    times1 = [float(line.strip()) for line in f]

with open('7_iterations/dynamic_50_times.txt', 'r') as f:
    times2 = [float(line.strip()) for line in f]

with open('7_iterations/dynamic_100_times.txt', 'r') as f:
    times3 = [float(line.strip()) for line in f]

with open('7_iterations/dynamic_200_times.txt', 'r') as f:
    times4 = [float(line.strip()) for line in f]

# Create an array for the indices
nodes1 = np.arange(25, 2501, 25)
nodes2 = np.arange(50, 2501, 50)
nodes3 = np.arange(100, 2501, 100)
nodes4 = np.arange(200, 2501, 200)

# Create the plot
fig, ax = plt.subplots()
ax.set_prop_cycle(color=cols)
plt.plot(nodes1, times1, marker='x', label='25 nodes')
plt.plot(nodes2, times2, marker='x', label='50 nodes')
plt.plot(nodes3, times3, marker='x', label='100 nodes')
plt.plot(nodes4, times4, marker='x', label='200 nodes')

# Add title and labels
plt.title('Compositional Analysis')
plt.xlabel('Number of nodes')
plt.ylabel('Inference time (s)')
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# cols = ['#fab36e', '#fa977d', '#ea8391', '#ca77a2', '#9f72aa', '#6c6ea5', '#376794']

# Load the data from the file
with open('10_iterations/dynamic_25_times.txt', 'r') as f:
    times1 = [float(line.strip()) for line in f]

with open('10_iterations/dynamic_50_times.txt', 'r') as f:
    times2 = [float(line.strip()) for line in f]

with open('10_iterations/dynamic_100_times.txt', 'r') as f:
    times3 = [float(line.strip()) for line in f]

with open('10_iterations/dynamic_200_times.txt', 'r') as f:
    times4 = [float(line.strip()) for line in f]

# Create an array for the indices
nodes1 = np.arange(25, 2501, 25)
nodes2 = np.arange(50, 2501, 50)
nodes3 = np.arange(100, 2501, 100)
nodes4 = np.arange(200, 2501, 200)

# Create the plot
fig, ax = plt.subplots()
ax.set_prop_cycle(color=cols)
plt.plot(nodes1, times1, marker='x', label='25 nodes')
plt.plot(nodes2, times2, marker='x', label='50 nodes')
plt.plot(nodes3, times3, marker='x', label='100 nodes')
plt.plot(nodes4, times4, marker='x', label='200 nodes')

# Add title and labels
plt.title('Compositional Analysis')
plt.xlabel('Number of nodes')
plt.ylabel('Inference time (s)')
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()
